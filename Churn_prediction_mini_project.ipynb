# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

df = pd.read_csv('data_regression.csv')
df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743  Female   36                     62
# 1  2015       100643  340-5930  Female   39                    149
# 2  2015       100756  372-3750  Female   65                    126
# 3  2015       101595  331-4902  Female   24                    131
# 4  2015       101653  351-8398  Female   40                    191
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82               1
# ...

# %%
df.tail()
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 1995  2015       997132  385-7387  Female   54                     75
# 1996  2015       998086  383-9255    Male   45                    127
# 1997  2015       998474  353-2080     NaN   53                     94
# 1998  2015       998934  359-7788    Male   40                     94
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 1995           no             yes               182.25                11.3
# 1996           no              no               273.45                 9.3
# 1997           no              no               128.85                15.6
# 1998           no              no               178.05                10.4
# 1999           no              no               326.70                10.3
#
#       maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# ...

# %%
# multi_screen vs gender

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['multi_screen'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='gender', y='multi_screen', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# no_of_days_subscribed vs weekly_mins_watched

from matplotlib import pyplot as plt
df.plot(kind='scatter', x='no_of_days_subscribed', y='weekly_mins_watched', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   1972 non-null   float64
# ...

# %%
#dropping null values
df.dropna()
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409-8743  Female   36                     62
# 1     2015       100643  340-5930  Female   39                    149
# 2     2015       100756  372-3750  Female   65                    126
# 3     2015       101595  331-4902  Female   24                    131
# 4     2015       101653  351-8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1990  2015       993714  364-1969    Male   32                     61
# 1991  2015       993815  387-5891    Male   49                     50
# 1992  2015       994954  329-3222  Female   42                    119
# 1996  2015       998086  383-9255    Male   45                    127
# 1999  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
#mapping
df['gender'] = df['gender'].map({'Male': 1, 'Female': 0}).dropna().astype(int)
df['multi_screen'] = df['multi_screen'].map({'yes': 1, 'no': 0}).dropna().astype(int)
df['mail_subscribed'] = df['mail_subscribed'].map({'yes': 1, 'no': 0}).dropna().astype(int)

# %%
#convert to numeric values
df['churn'] = pd.to_numeric(df['churn'], errors='coerce').dropna().astype(int)

# %%
#Filling missing NaN values
df['gender'] = df['gender'].fillna(df['gender'].median())
df['multi_screen'] = df['multi_screen'].fillna(df['multi_screen'].median())
df['mail_subscribed'] = df['mail_subscribed'].fillna(df['mail_subscribed'].median())
df['churn'] = df['churn'].fillna(df['churn'].median())

# %%
#checking NaN values 
print(df['gender'].isna().sum())
print(df['multi_screen'].isna().sum())
print(df['mail_subscribed'].isna().sum())
print(df['churn'].isna().sum())
# Out:
# 0
# 0
# 0
# 0

# %%
df.head(10)
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743     0.0   36                     62
# 1  2015       100643  340-5930     0.0   39                    149
# 2  2015       100756  372-3750     0.0   65                    126
# 3  2015       101595  331-4902     0.0   24                    131
# 4  2015       101653  351-8398     0.0   40                    191
# 5  2015       101953  329-6603     1.0   31                     65
# 6  2015       103051  416-1845     1.0   54                     59
# 7  2015       103225  348-7193     0.0   40                     50
# 8  2015       103408  413-4039     1.0   61                    205
# 9  2015       103676  338-5207     1.0   31                     63
#
#    multi_screen  mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0             0                0               148.35                12.2
# 1             0                0               294.45                 7.7
# ...

# %%
# Check for other columns with object dtype and convert them to numeric if necessary

for col in df.select_dtypes(include=['object']).columns:
    # If column is not 'phone_no' or 'customer_id', convert to numeric
    if col not in ['phone_no', 'customer_id']:
        try:
            df[col] = pd.to_numeric(df[col], errors='coerce').fillna(-1).astype(int)
        except ValueError:
            print(f"Column '{col}' could not be converted to numeric. Please inspect its values.")

# %% [markdown]
# FEATURE SELECTION

# %%
#Feature selection
X= df.drop(columns= ['phone_no', 'customer_id', 'year','churn'])
y= df['churn']

# %%
y.head()
# Out:
# 0    0.0
# 1    0.0
# 2    1.0
# 3    0.0
# 4    0.0
# Name: churn, dtype: float64

# %% [markdown]
# DATA SPLITTING

# %%
#splitting of data 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3, random_state=0)

# %%
print("Unique classes in y_test:", set(y_test))
# Out:
# Unique classes in y_test: {0.0, 1.0}

# %% [markdown]
# MODEL

# %%
from sklearn.tree import DecisionTreeClassifier

t= DecisionTreeClassifier()
t
# Out:
# DecisionTreeClassifier()

# %%
t.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = t.predict(X_test)

# %% [markdown]
# EVALUATION METRICS

# %%
#Evaluation metrics
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
print("Accuracy score: ")
accuracy_score(y_test, y_predict)
# Out:
# Accuracy score:
# 0.8616666666666667

# %%
print("F1 score-macro: ")
f1_score(y_test, y_predict, average='macro')
# Out:
# F1 score-macro:
# 0.7393748135587899

# %%
print("F1 score-micro: ")
f1_score(y_test, y_predict, average='micro')
# Out:
# F1 score-micro:
# 0.8616666666666667

# %%
print("F1 score-weighted: ")
f1_score(y_test, y_predict, average='weighted')
# Out:
# F1 score-weighted:
# 0.8661298729844725

# %%
print("Precision score-macro: ")
precision_score(y_test, y_predict, average='macro')
# Out:
# Precision score-macro:
# 0.7256673753838885

# %%
print("Precision score-micro: ")
precision_score(y_test, y_predict, average='micro')
# Out:
# Precision score-micro:
# 0.8616666666666667

# %%
print("Precision score-weighted: ")
precision_score(y_test, y_predict, average='weighted')
# Out:
# Precision score-weighted:
# 0.8719696432789984

# %%
print("Recall score-macro: ")
recall_score(y_test, y_predict, average='macro')
# Out:
# Recall score-macro:
# 0.7568394165490354

# %%
print("Recall score-micro: ")
recall_score(y_test, y_predict, average='micro')
# Out:
# Recall score-micro:
# 0.8616666666666667

# %%
print("Recall score-weighted: ")
recall_score(y_test, y_predict, average='weighted')
# Out:
# Recall score-weighted:
# 0.8616666666666667

# %% [markdown]
# CLASSIFICATION REPORT

# %%
#Classification report 
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import pandas as pd

cr= print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.90      0.92       513
#          1.0       0.52      0.61      0.56        87
#
#     accuracy                           0.86       600
#    macro avg       0.73      0.76      0.74       600
# weighted avg       0.87      0.86      0.87       600

# %%
#converting classification report as a dictionary
cr_dict = classification_report(y_test, y_predict, output_dict=True)

# Convert the dictionary to a DataFrame
cr_df = pd.DataFrame(cr_dict).transpose()

# Drop support column for plot
metrics_to_plot = cr_df.drop(columns=['support'])

# Plot classification report
plt.figure(figsize=(10, 6))
sns.heatmap(metrics_to_plot, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Classification Report')
plt.xlabel('Metrics')
plt.ylabel('Classes')
plt.show()

# %%
#Confusion metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm= confusion_matrix(y_test, y_predict)
cm
# Out:
# array([[464,  49],
#        [ 34,  53]], dtype=int64)

# %%
import matplotlib.pyplot as plt

# Predict with the best model
y_predict = t.predict(X_test)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=t.classes_)
disp.plot(cmap=plt.cm.Purples)

plt.title("Confusion Matrix - Decision Tree")
plt.grid(False)
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt


#Get predicted probabilities for class 1 (churn = 1)
y_probability = t.predict_proba(X_test)[:, 1]

def plot_roc_curve(y_test, y_probability, t):
    fpr, tpr, thresholds = roc_curve(y_test, y_probability)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='red', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC-AUC Curve for {t}')
    plt.legend(loc="lower right")
    plt.grid()
    plt.show()

# Call the function
plot_roc_curve(y_test, y_probability, 'Decision Tree')

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Plot feature importance
plt.barh(X.columns, t.feature_importances_, color='lightgreen')
plt.xlabel('Importance')
plt.title('Feature Importance')
plt.gca().invert_yaxis()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(30, 25))
plot_tree(t, filled=True, feature_names=X.columns, class_names=['Not Churn', 'Churn'], node_ids=True, fontsize=3)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 20))
plot_tree(t, filled=True, feature_names=X.columns, class_names=['Not Churn', 'Churn'], max_depth = 3, node_ids=True, fontsize=10)
plt.show()

# %%
#HYPER-PARAMETER TUNING- gridsearchCV

t.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
from sklearn.model_selection import GridSearchCV

grid= GridSearchCV(t, param_grid=param_grid, cv=5, scoring='accuracy', verbose=1)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy', verbose=1)

# %%
t_2 = DecisionTreeClassifier(max_depth=3,criterion='entropy')
t_2.fit(X_train, y_train) # This line is added to fit the model
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
y_pred = grid.predict(X_test)

# %%
print("Best Parameters:\n", grid.best_params_)
# Out:
# Best Parameters:
#  {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
#Classification report- GridSearchCV

print("\n📊 Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.95      0.92       513
#          1.0       0.55      0.33      0.41        87
#
#     accuracy                           0.86       600
#    macro avg       0.72      0.64      0.67       600
# weighted avg       0.84      0.86      0.85       600

# %%
print("Best Score: ", grid.best_score_)
print("Best Estimator: ", grid.best_estimator_)
# Out:
# Best Score:  0.9014285714285715
# Best Estimator:  DecisionTreeClassifier(criterion='entropy', max_depth=10, max_features='sqrt',
#                        min_samples_leaf=4, min_samples_split=10)

# %%
#Parameters used in GridSearchCV

print("Model Parameters: \n", grid.get_params())
# Out:
# Model Parameters:
#  {'cv': 5, 'error_score': nan, 'estimator__ccp_alpha': 0.0, 'estimator__class_weight': None, 'estimator__criterion': 'gini', 'estimator__max_depth': None, 'estimator__max_features': None, 'estimator__max_leaf_nodes': None, 'estimator__min_impurity_decrease': 0.0, 'estimator__min_samples_leaf': 1, 'estimator__min_samples_split': 2, 'estimator__min_weight_fraction_leaf': 0.0, 'estimator__monotonic_cst': None, 'estimator__random_state': None, 'estimator__splitter': 'best', 'estimator': DecisionTreeClassifier(), 'n_jobs': None, 'param_grid': {'criterion': ['gini', 'entropy'], 'max_depth': [None, 10, 20, 30], 'min_samples_split': [2, 5, 10], 'min_samples_leaf': [1, 2, 4], 'max_features': ['auto', 'sqrt', 'log2']}, 'pre_dispatch': '2*n_jobs', 'refit': True, 'return_train_score': False, 'scoring': 'accuracy', 'verbose': 1}

# %%
#Plotting after using hyperparameter tuning

import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 20))
plot_tree(t_2, filled=True, feature_names=X.columns, class_names=['Not Churn', 'Churn'], node_ids=True, max_depth=3, fontsize=10)
plt.show()

# %%
#Saving model- joblib

import joblib

joblib.dump(t, 'decision_tree_model_t.pkl')
# Out:
# ['decision_tree_model_t.pkl']

# %%
joblib.dump(t_2, 'decision_tree_model_t_2.pkl')
# Out:
# ['decision_tree_model_t_2.pkl']
